# %% [markdown]
# # Publications markdown generator for academicpages
#
# Takes a set of bibtex of publications and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)).
#
# The core python code is also in `pubsFromBibs.py`.
# Run either from the `markdown_generator` folder after replacing updating the publist dictionary with:
# * bib file names
# * specific venue keys based on your bib file preferences
# * any specific pre-text for specific files
# * Collection Name (future feature)
#
# TODO: Make this work with other databases of citations,
# TODO: Merge this with the existing TSV parsing solution

# %%
from pybtex.database.input import bibtex
import pybtex.database.input.bibtex 
from time import strptime
import string
import html
import os
import re

# %%
#todo: incorporate different collection types rather than a catch all publications, requires other changes to template
publist = {
    # "proceeding": {
    #     "file" : "proceedings.bib",
    #     "venuekey": "booktitle",
    #     "venue-pretext": "In the proceedings of ",
    #     "collection" : {"name":"publications",
    #                     "permalink":"/publication/"}
        
    # },
    "journal":{
        "file": "mypubs.bib",
        "venuekey" : "journal",
        "venue-pretext" : "",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
    } 
}

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text)

# %%
for pubsource in publist:
    parser = bibtex.Parser()
    bibdata = parser.parse_file(publist[pubsource]["file"])

    #loop through the individual references in a given bibtex file
    for bib_id in bibdata.entries:
        #reset default date
        pub_year = "1900"
        pub_month = "01"
        pub_day = "01"
        
        b = bibdata.entries[bib_id].fields
        
        try:
            pub_year = f'{b["year"]}'

            #todo: this hack for month and day needs some cleanup
            if "month" in b.keys(): 
                if(len(b["month"])<3):
                    pub_month = "0"+b["month"]
                    pub_month = pub_month[-2:]
                elif(b["month"] not in range(12)):
                    tmnth = strptime(b["month"][:3],'%b').tm_mon   
                    pub_month = "{:02d}".format(tmnth) 
                else:
                    pub_month = str(b["month"])
            if "day" in b.keys(): 
                pub_day = str(b["day"])

                
            pub_date = pub_year+"-"+pub_month+"-"+pub_day
            
            #strip out {} as needed (some bibtex entries that maintain formatting)
            clean_title = b["title"].replace("{", "").replace("}","").replace("\\","").replace(" ","-")    

            url_slug = re.sub("\\[.*\\]|[^a-zA-Z0-9_-]", "", clean_title)
            url_slug = url_slug.replace("--","-")

            md_filename = (str(pub_date) + "-" + url_slug + ".md").replace("--","-")
            html_filename = (str(pub_date) + "-" + url_slug).replace("--","-")

            #Build Citation from text
            citation = ""

            #citation authors - todo - add highlighting for primary author?
            for author in bibdata.entries[bib_id].persons["author"]:
                try:
                    citation = citation+" "+author.first_names[0]+" "+author.last_names[0]+", "
                except:
                    citation = citation + " " + author.last_names[0]
            #citation title
            citation = citation + "\"" + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + ".\""

            #add venue logic depending on citation type
            venue = publist[pubsource]["venue-pretext"]+b[publist[pubsource]["venuekey"]].replace("{", "").replace("}","").replace("\\","")

            citation = citation + " " + html_escape(venue)
            citation = citation + ", " + pub_year + "."

            
            ## YAML variables
            md = "---\ntitle: \""   + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + '"\n'
            
            md += """collection: """ +  publist[pubsource]["collection"]["name"]

            md += """\npermalink: """ + publist[pubsource]["collection"]["permalink"]  + html_filename
            
            note = False
            if "note" in b.keys():
                if len(str(b["note"])) > 5:
                    md += "\nexcerpt: '" + html_escape(b["note"]) + "'"
                    note = True

            md += "\ndate: " + str(pub_date) 

            md += "\nvenue: '" + html_escape(venue) + "'"
            
            url = False
            if "url" in b.keys():
                if len(str(b["url"])) > 5:
                    md += "\npaperurl: '" + b["url"] + "'"
                    url = True

            md += "\ncitation: '" + html_escape(citation) + "'"

            md += "\n---"

            
            ## Markdown description for individual page
            if note:
                md += "\n" + html_escape(b["note"]) + "\n"

            if url:
                md += "\n[Access paper here](" + b["url"] + "){:target=\"_blank\"}\n" 
            else:
                md += "\nUse [Google Scholar](https://scholar.google.com/scholar?q="+html.escape(clean_title.replace("-","+"))+"){:target=\"_blank\"} for full citation"

            md_filename = os.path.basename(md_filename)

            with open("../_publications/" + md_filename, 'w', encoding="utf-8") as f:
                f.write(md)
            print(f'SUCESSFULLY PARSED {bib_id}: \"', b["title"][:60],"..."*(len(b['title'])>60),"\"")
        # field may not exist for a reference
        except KeyError as e:
            print(f'WARNING Missing Expected Field {e} from entry {bib_id}: \"', b["title"][:30],"..."*(len(b['title'])>30),"\"")
            continue
# Out:
# SUCESSFULLY PARSED Adamatzky2014space: " {Slime mould analogue models of space exploration and planet ... "
# WARNING Missing Expected Field 'journal' from entry Adamatzky2016LogicBook: " {Logical Gates and Circuits Im ... "
# SUCESSFULLY PARSED Adamatzky2015actinAutomata: " {Actin Automata: Phenomenology and Localizations}  "
# SUCESSFULLY PARSED Adamatzky2017paths: " {East-West paths to unconventional computing}  "
# WARNING Missing Expected Field 'journal' from entry Adamatzky2017phychip: " {PhyChip : Growing Computers w ... "
# WARNING Missing Expected Field 'journal' from entry Adamatzky2017plants: " {Computers from plants we neve ... "
# SUCESSFULLY PARSED Adamatzky2019: " {Liquid Marble Photosensor}  "
# SUCESSFULLY PARSED Adamatzky2020: " {On Boolean gates in fungal colony}  "
# WARNING Missing Expected Field 'journal' from entry Adamatzky2022lms: " {Sensing and Computing with Li ... "
# SUCESSFULLY PARSED Adamatzky2022fe: " Fungal Electronics  "
# WARNING Missing Expected Field 'journal' from entry Adamatzky2023booleanfungus: " {On Boolean gates in fungal co ... "
# WARNING Missing Expected Field 'journal' from entry Adamatzky2023stimulatingfungi: " {On stimulating fungi Pleurotu ... "
# WARNING Missing Expected Field 'journal' from entry Adamatzky2024actinautomata: " {Actin Automata: Phenomenology ... "
# SUCESSFULLY PARSED Assaf2016: " {Emergent Behaviors in a Bio-Inspired Platform Controlled by ... "
# SUCESSFULLY PARSED Chiolerio2019: " {On resistance switching and oscillations in tubulin microtu ... "
# SUCESSFULLY PARSED Costello2015: " {Conducting polymer-coated Physarum polycephalum towards the ... "
# SUCESSFULLY PARSED Deshibi2021: " Stimulating Fungi Pleurotus ostreatus with Hydrocortisone  "
# WARNING Missing Expected Field 'journal' from entry Dillon2019: " {Interspecies Urban Planning,  ... "
# SUCESSFULLY PARSED Draper2019: " {Mapping outcomes of liquid marble collisions}  "
# SUCESSFULLY PARSED Draper2019chip: " {Contactless Sensing of Liquid Marbles for Detection and Cha ... "
# SUCESSFULLY PARSED Fullarton2018: " {Evaporation, Lifetime, and Robustness Studies of Liquid Mar ... "
# WARNING Missing Expected Field 'journal' from entry Gale2017: " {Physarum Inspired Audio: From ... "
# SUCESSFULLY PARSED Gale2014: " {Drop-coated titanium dioxide memristors}  "
# SUCESSFULLY PARSED Gizzie2016a: " {Living Wires - Effects of Size and Coating of Gold Nanopart ... "
# SUCESSFULLY PARSED Gizzie2016b: " {On modulating the Physarum polycephalum plasmodium's electr ... "
# SUCESSFULLY PARSED Gizzie2016c: " {On hybridising lettuce seedlings with nanoparticles and the ... "
# SUCESSFULLY PARSED Varsani2025: " Summary of taxonomy changes ratified by the International Co ... "
# SUCESSFULLY PARSED Hughes2025: " Summary of taxonomy changes ratified by the International Co ... "
# SUCESSFULLY PARSED Sabanadzovic2025: " Summary of taxonomy changes ratified by the International Co ... "
# SUCESSFULLY PARSED Turner2025: " Summary of taxonomy changes ratified by the International Co ... "
# SUCESSFULLY PARSED Rubino2025: " Summary of taxonomy changes ratified by the International Co ... "
# SUCESSFULLY PARSED Krupovic2025: " Summary of taxonomy changes ratified by the International Co ... "
# SUCESSFULLY PARSED Zerbini2025: " Summary of taxonomy changes ratified by the International Co ... "
# SUCESSFULLY PARSED Jones2015: " {Representation of shape mediated by environmental stimuli i ... "
# WARNING Missing Expected Field 'journal' from entry Martinez2015: " {Majority Gates and Circular C ... "
# SUCESSFULLY PARSED Mayne2026picorna: " Comprehensive hallmark gene sequence, genomic and structural ... "
# WARNING Missing Expected Field 'journal' from entry Mayne2021arts: " {Collapsing the Wave Function  ... "
# SUCESSFULLY PARSED Mayne2020vr: " {Virtual Reality for Teaching and Learning in Crime Scene In ... "
# SUCESSFULLY PARSED Mayne2019neuromorphic: " {Neuromorphic Liquid Marbles with Aqueous Carbon Nanotube Co ... "
# SUCESSFULLY PARSED Mayne2024castanet: " Castanet: A pipeline for rapid analysis of targeted multi-pa ... "
# SUCESSFULLY PARSED Mayne2024gravity: " GRAViTy-V2: a grounded viral taxonomy application  "
# WARNING Missing Expected Field 'journal' from entry Mayne2018atlas1: " {Programming Ciliary Object Ma ... "
# WARNING Missing Expected Field 'journal' from entry Mayne2018atlas2: " {Biological preliminaries for  ... "
# SUCESSFULLY PARSED Mayne2018vesicles: " {Towards experimental P-systems using multivesicular liposom ... "
# WARNING Missing Expected Field 'journal' from entry Mayne2016preliminaries: " {Biology of the Physarum polyc ... "
# WARNING Missing Expected Field 'journal' from entry Mayne2013: " {On the internalisation of mag ... "
# SUCESSFULLY PARSED Mayne2017embryogenesisReview: " {Book Review: Embryogenesis Explained}  "
# SUCESSFULLY PARSED Mayne2015optical: " {Slime mould foraging behaviour as optically coupled logical ... "
# WARNING Missing Expected Field 'journal' from entry Mayne2016advancesNanotech: " {Slime Mould Nanotechnology}  "
# WARNING Missing Expected Field 'journal' from entry Mayne2016advancesFPGA: " {Towards a Slime Mould-FPGA In ... "
# WARNING Missing Expected Field 'journal' from entry Mayne2015biotech: " {Slime mould biotechnology}  "
# WARNING Missing Expected Field 'journal' from entry Mayne2016orchestrated: " {Orchestrated Biocomputation:  ... "
# WARNING Missing Expected Field 'journal' from entry Mayne2015ecal: " {Slime mould actin sensoriactu ... "
# SUCESSFULLY PARSED Mayne2016natcomp: " {Cellular automata modelling of slime mould actin network si ... "
# WARNING Missing Expected Field 'journal' from entry Mayne2014formalisation: " {The Physarum polycephalum act ... "
# SUCESSFULLY PARSED Mayne2015nl: " {Towards Hybrid Nanostructure-Slime Mould Devices}  "
# SUCESSFULLY PARSED Mayne2015vesicles: " {On the Computing Potential of Intracellular Vesicles}  "
# SUCESSFULLY PARSED Mayne2014cib: " {On the role of the plasmodial cytoskeleton in facilitating  ... "
# SUCESSFULLY PARSED Mayne2015oscillator: " {On coupled oscillator dynamics and incident behaviour patte ... "
# SUCESSFULLY PARSED Mayne2011: " {On the Internalisation, Intraplasmodial Carriage and Excret ... "
# SUCESSFULLY PARSED Mayne2015fpga: " {Towards a slime Mould-FPGA interface}  "
# SUCESSFULLY PARSED Mayne2017toxicity: " {Toxicity and applications of internalised magnetite nanopar ... "
# SUCESSFULLY PARSED Mayne2017sorting: " {Particle Sorting by Paramecium Cilia Arrays}  "
# WARNING Missing Expected Field 'author' from entry Mayne2018atlas: " Atlas of Cilia Bioengineering  ... "
# SUCESSFULLY PARSED Mayne2019smart: " {On measuring nanoparticle toxicity and clearance with Param ... "
# SUCESSFULLY PARSED Mayne2023fungal: " Propagation of electrical signals by fungi  "
# WARNING Missing Expected Field 'journal' from entry Mayne2017shortest: " When the path is never shortes ... "
# SUCESSFULLY PARSED Mayne2025tps: " Virus Taxonomy Proposal Summaries: A Searchable and Citeable ... "
# SUCESSFULLY PARSED Mcclure2024f8: " Reconstruction of the historic time course of blood‐borne vi ... "
# SUCESSFULLY PARSED Monttinen2025_rdrp: " Revealing deep evolutionary relationships between RNA viruse ... "
# SUCESSFULLY PARSED Nomura2020: " Spontaneous and Driven Growth of Multicellular Lipid Compart ... "
# SUCESSFULLY PARSED Nurmi2025covid: " Individual patient and donor seroprofiles in convalescent pl ... "
# SUCESSFULLY PARSED Phillips2019: " {Marimo machines: oscillators, biosensors and actuators}  "
# SUCESSFULLY PARSED Phillips2017: " {What if houses were powered by milk?}  "
# SUCESSFULLY PARSED Secret2025hiv: " Bioinformatic identification of lentivirus transfer plasmid  ... "
# SUCESSFULLY PARSED Simmonds2025ictv: " Changes to virus taxonomy, the international code of virus c ... "
# SUCESSFULLY PARSED Simmonds2025flavi: " Taxonomic expansion and reorganization of {\it Flaviviridae}  "
# SUCESSFULLY PARSED Tsompanas2015: " {A Cellular Automata Bioinspired Algorithm Designing Data Tr ... "
# SUCESSFULLY PARSED Philips2022chlorella: " Chlorella sensors in liquid marbles and droplets  "
# SUCESSFULLY PARSED Philips2022rover: " Marimo Actuated Rover Systems  "
# SUCESSFULLY PARSED Walter2016: " {On hybrid circuits exploiting thermistive properties of sli ... "
# SUCESSFULLY PARSED Whiting2018: " {A Parallel Modular Biomimetic Cilia Sorting Platform}  "
# SUCESSFULLY PARSED Whiting2018closedLoop: " {A Cilia-inspired Closed-loop Sensor-actuator Array}  "
# SUCESSFULLY PARSED Yang2019: " {A Bio-inspired Network Design Method for Intelligent Transp ... "

# %%
md_filename
# Out:
# '2019-01-01-A-Bio-inspired-Network-Design-Method-for-Intelligent-Transportation.md'
